# %%
def guessNumber(startRange, endRange):
  if startRange>endRange:
    return True

  mid=(startRange+endRange)//2

  print(f"Is the number{mid}?(Yes/No)", end="")
  user=input().strip()

  if user in("Yes","yes"):
    print("Yayayyayayaya!!!! Successfully Guessed Number.")
    return False

  elif user in("No","no"):
    print(f"Is the actual Number greater than {mid}? (Yes/No):", end="")
    user=input().strip()

    if user in("Yes", "yes"):
      return guessNumber(mid + 1, endRange)
    elif user in ("No", "no"):
      return guessNumber(startRange, mid - 1)
    else:
            print("Invalid input. Please enter 'Yes' or 'No'.")
            return guessNumber(startRange, endRange)
  else:
        print("Invalid input. Please enter 'Yes' or 'No'.")
        return guessNumber(startRange, endRange)

if __name__ == "__main__":
    print("Number Guessing Game in Python!!!!!")

    startRange = int(input("Enter Start Range: "))
    endRange = int(input("Enter End Range: "))

    print(f"Think of a number between {startRange} and {endRange}. I will try to guess it!!!")

    out = guessNumber(startRange, endRange)

    if out:
        print("Couldn't guess it.... Are you sure you answered correctly?")
# Out:
# Number Guessing Game in Python!!!!!
# Enter Start Range: 56
# Enter End Range: 100
# Think of a number between 56 and 100. I will try to guess it!!!
# Is the number78?(Yes/No)no
# Is the actual Number greater than 78? (Yes/No):no
# Is the number66?(Yes/No)yes
# Yayayyayayaya!!!! Successfully Guessed Number.
